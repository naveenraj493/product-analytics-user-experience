# %% [markdown]
# # Product Analytics Project
#
# ## 01. Data Cleaning

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load Published Dataset
#
# This repository includes only the anonymized version of the survey.
#
# The original survey export contained personally identifiable information (PII), including respondent IDs, submission IDs, and email addresses. These fields were removed before publication.
#
# The workflow below demonstrates the validation and standardization performed on the published dataset.

# %%
# Public version of the dataset used for this portfolio.
# The original raw survey responses are excluded to protect respondent privacy.
df = pd.read_csv("../data/processed/survey_cleaned_public.csv")

# %%
# Verify the public dataset loaded successfully
print(f"Dataset shape: {df.shape}")

print("\nDataset information:")
df.info()

print("\nColumn names:")
for column in df.columns:
    print(f"- {column}")

# %% [markdown]
# ## Initial Dataset Inspection

# %%
df["Submitted at"] = pd.to_datetime(df["Submitted at"])

print("Earliest response:", df["Submitted at"].min())
print("Latest response:", df["Submitted at"].max())

# %% [markdown]
# ## Create Dataset Summary

# %%
summary = pd.DataFrame({
    "Column": df.columns,
    "Data Type": df.dtypes.astype(str),
    "Missing Values": df.isnull().sum(),
    "Unique Values": df.nunique()
})

summary

# %%
summary.to_csv("../data/processed/data_summary.csv", index=False)

# %% [markdown]
# ## Create Working Copy

# %%
# Create a working copy of the dataset
clean_df = df.copy()

# %% [markdown]
# ## Remove Sensitive Columns (Original Cleaning Step)

# %%
columns_to_remove = [
    "Submission ID",
    "Respondent ID",
    "If you would like to receive emails about IGC or future opportunities? Drop your email below!"
]

clean_df = clean_df.drop(
    columns=columns_to_remove,
    errors="ignore"
)

# %% [markdown]
# ## Standardize Column Names

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

# %%
with open("../docs/column_names.txt", "w") as f:
    for i, col in enumerate(clean_df.columns, start=1):
        f.write(f"{i}. {col}\n")

# %%
rename_dict = {

    # -------------------------
    # Metadata
    # -------------------------
    "Submitted at": "submitted_at",

    # -------------------------
    # User Profile
    # -------------------------
    "Which age category do you belong to?": "age_group",
    "Which platform do you play BGMI on? ": "platform",
    "How long have you been playing BGMI?": "years_playing",
    "How often do you play the game? ": "play_frequency",
    "What is your primary game mode? ": "primary_game_mode",

    # -------------------------
    # Product Experience
    # -------------------------
    "How would you rate your overall BGMI experience as of today? (On a scale of 0-10)": "overall_experience_score",
    "Compared to six months ago, the game feels": "experience_vs_6_months",
    "What has changed the most in BGMI recently? ": "biggest_recent_change",
    "How do you often feel about new BGMI updates? ": "update_sentiment",

    # -------------------------
    # Update Preferences
    # -------------------------
    "What do you enjoy most in new updates (Select all that apply)?": "liked_update_features",

    "What do you enjoy most in new updates (Select all that apply)? (New maps)": "liked_new_maps",

    "What do you enjoy most in new updates (Select all that apply)? (New modes)": "liked_new_modes",

    "What do you enjoy most in new updates (Select all that apply)? (Collaborations)": "liked_collaborations",

    "What do you enjoy most in new updates (Select all that apply)? (Gameplay improvements)": "liked_gameplay_improvements",

    "What do you enjoy most in new updates (Select all that apply)? (Events & rewards)": "liked_events_rewards",

    "What do you enjoy most in new updates (Select all that apply)? (Graphics improvements)": "liked_graphics_improvements",

    "What do you enjoy most in new updates (Select all that apply)? (Weapon balance)": "liked_weapon_balance",

    "What do you enjoy most in new updates (Select all that apply)? (Other)": "liked_other",

    "What do you dislike about the updates? ": "update_dislikes",
}

# %% [markdown]
# ### Technical Issues

# %%
rename_dict.update({

    "How often do you encounter bugs while playing?":
        "bug_frequency",

    "How often do you experience server errors?":
        "server_error_frequency",

    "Which issues do you face most often? (Select all that apply)":
        "reported_issues",

    "Which issues do you face most often? (Select all that apply) (Server error)":
        "issue_server_error",

    "Which issues do you face most often? (Select all that apply) (Game crash)":
        "issue_game_crash",

    "Which issues do you face most often? (Select all that apply) (FPS drops)":
        "issue_fps_drops",

    "Which issues do you face most often? (Select all that apply) (Ping spikes)":
        "issue_ping_spikes",

    "Which issues do you face most often? (Select all that apply) (Matchmaking issues)":
        "issue_matchmaking",

    "Which issues do you face most often? (Select all that apply) (Audio bugs)":
        "issue_audio_bugs",

    "Which issues do you face most often? (Select all that apply) (Character movement glitches)":
        "issue_movement_glitches",

    "Which issues do you face most often? (Select all that apply) (Texture/rendering issues)":
        "issue_texture_rendering",

    "Which issues do you face most often? (Select all that apply) (Login issues)":
        "issue_login",

    "Which issues do you face most often? (Select all that apply) (Other)":
        "issue_other",

    "Which issue frustrates you the most? ":
        "most_frustrating_issue",

    "How would you rate the game's performance on your device? (On a scale of 0-10)":
        "device_performance_score",

    "Does the game run smoothly on your device? ":
        "runs_smoothly",

    "Approximately how many server erros have you experienced in the past 30 days? ":
        "server_errors_last_30_days",

    "Have bugs ever made you feel like deleting the game? ":
        "bugs_caused_delete_intent"

})

# %% [markdown]
# ### Developer Trust, Security & Product Strategy

# %%
rename_dict.update({

    # -------------------------
    # Developer Trust
    # -------------------------

    "Do you feel the BGMI developers listen to community feedback?":
        "developers_listen",

    "Do you think player-reported issues receive enough attention? ":
        "player_reports_receive_attention",

    "How satisfied are you with the speed at which bugs are fixed? (On a scale of 0-10)":
        "bug_fix_speed_score",

    # -------------------------
    # Security
    # -------------------------

    "How often do you encounter hackers or cheaters?":
        "cheater_frequency",

    "Do you think the current anti-cheat system is effective?":
        "anti_cheat_effective",

    # -------------------------
    # Product Strategy
    # -------------------------

    "Do you feel BGMI focuses too much on collaborations and cosmetics instead of improving gameplay?":
        "focus_too_much_on_collaborations",

    "Would you prefer the next major update to focus primarily on bug fixes and optimization rather than new content? ":
        "prefer_bug_fix_updates",

    # -------------------------
    # Developer Priorities
    # -------------------------

    "Which should be the developers' highest priority? (Select all that apply)":
        "developer_priorities",

    "Which should be the developers' highest priority? (Select all that apply) (Bug fixes)":
        "priority_bug_fixes",

    "Which should be the developers' highest priority? (Select all that apply) (Anti-cheat improvements)":
        "priority_anti_cheat",

    "Which should be the developers' highest priority? (Select all that apply) (Server stability)":
        "priority_server_stability",

    "Which should be the developers' highest priority? (Select all that apply) (Performance optimization)":
        "priority_performance",

    "Which should be the developers' highest priority? (Select all that apply) (New content)":
        "priority_new_content",

    "Which should be the developers' highest priority? (Select all that apply) (New maps)":
        "priority_new_maps",

    "Which should be the developers' highest priority? (Select all that apply) (Better matchmarking)":
        "priority_better_matchmaking",

    # Trust & Product Direction

    "Has your trust in BGMI improved or declined over the past year? ":
        "trust_change",

    "Do you believe BGMI is moving in the right direction?":
        "product_direction",

    "Do you believe BGMI is moving in the right direction? (Definitely Yes)":
        "direction_definitely_yes",

    "Do you believe BGMI is moving in the right direction? (Probably Yes)":
        "direction_probably_yes",

    "Do you believe BGMI is moving in the right direction? (Not Sure)":
        "direction_not_sure",

    "Do you believe BGMI is moving in the right direction? (Probably No)":
        "direction_probably_no",

    "Do you believe BGMI is moving in the right direction? (Definitely No)":
        "direction_definitely_no"

})

# %% [markdown]
# ### Community Engagement & Feedback Channels

# %%
rename_dict.update({

    # -------------------------
    # Community Engagement
    # -------------------------

    "How often do you discuss BGMI with friends or on social media?":
        "community_discussion_frequency",

    # -------------------------
    # Feedback Channels
    # -------------------------

    "Where do you usually share your feedback about BGMI? (Select all that apply)":
        "feedback_channels",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Official Discord)":
        "feedback_discord",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Instagram Comments)":
        "feedback_instagram_comments",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Instagram DMs)":
        "feedback_instagram_dms",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Instagram story tags)":
        "feedback_instagram_story",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (X(Twitter))":
        "feedback_x",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (YouTube)":
        "feedback_youtube",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Reddit)":
        "feedback_reddit",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (In-game support)":
        "feedback_ingame_support",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (I don't share feedback)":
        "feedback_do_not_share",

    "Where do you usually share your feedback about BGMI? (Select all that apply) (Other)":
        "feedback_other"

})

# %% [markdown]
# ### Open-ended Feedback

# %%
rename_dict.update({

    # -------------------------
    # Open-ended Feedback
    # -------------------------

    "Whats the biggest issue currently hurting the game? ":
        "biggest_product_issue"

})

clean_df = clean_df.rename(columns=rename_dict)

# %%
print("Cleaned Dataset Information")
clean_df.info()

# %% [markdown]
# ## Missing Value Assessment

# %%
clean_df.isnull().sum().sort_values(ascending=False)

# %% [markdown]
# ## Dataset Validation

# %%
clean_df.describe(include="all")

# %%
print(f"Dataset shape: {clean_df.shape}")

# %%
missing = (
    clean_df.isnull()
            .sum()
            .sort_values(ascending=False)
            .reset_index()
)

missing.columns = ["column", "missing_values"]

missing["missing_percent"] = (
    missing["missing_values"] / len(clean_df) * 100
).round(2)

missing

# %% [markdown]
# ## Data Quality Assessment
#
# The cleaned dataset was validated before export to PostgreSQL.
#
# Validation included:
#
# - Missing value assessment
# - Duplicate detection
# - Dataset dimensions
# - Descriptive statistics

# %% [markdown]
# ## Missing Value Assessment
#
# Only four open-ended survey questions contained missing values (26% to 32% missing).
#
# These questions were optional and required respondents to provide free-text responses. Missing values were retained because they represent legitimate non-responses rather than data quality issues.
#
# No numerical, categorical, or boolean variables contained missing values.

# %% [markdown]
# ## Duplicate Assessment
# The dataset was checked for duplicate records before export.

# %%
duplicates = clean_df.duplicated().sum()
print(f"Duplicate rows: {duplicates}")

# %% [markdown]
# ## Export Published Dataset

# %%
clean_df.to_csv(
    "../data/processed/survey_cleaned_public.csv",
    index=False
)

print("Published dataset saved successfully!")

# %% [markdown]
# ## Load Dataset into PostgreSQL

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:YOUR_PASSWORD@localhost:5432/postgres"
)

with engine.connect() as conn:
    print("Connected to PostgreSQL successfully!")

# %%
clean_df.to_sql(
    name="survey_cleaned",
    con=engine,
    if_exists="replace",
    index=False
)

print("Table created successfully!")
